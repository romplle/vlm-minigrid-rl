# %%
from datasets import load_from_disk
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
dataset_path = PROJECT_ROOT / "dataset"

# %%
ds = load_from_disk(dataset_path)
print(ds)
# Out:
# Dataset({
#     features: ['ego_image', 'global_image', 'prompt', 'action', 'action_id', 'episode_id', 'step', 'env_size', 'agent_pos', 'agent_dir'],
#     num_rows: 5280
# })

# %%
n = 5

print("ego_image: ")
display(ds[n]["ego_image"])

print("global_image: ")
display(ds[n]["global_image"])

print("\nprompt: ")
print(ds[n]["prompt"])

print("\naction: ", ds[n]["action"])

print("\naction_id: ", ds[n]["action_id"])

print("\nepisode_id: ", ds[n]["episode_id"])

print("\nstep: ", ds[n]["step"])

print("\nenv_size: ", ds[n]["env_size"])

print("\nagent_pos: ", ds[n]["agent_pos"])

print("\nagent_dir: ", ds[n]["agent_dir"])
# Out:
# ego_image:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>
# global_image:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256>
# prompt:
# You are a robot in a 2D grid world. You see a 7x7 partial RGB view in front of you.
# Your mission: get to the green goal square as quickly as possible.
# Choose the next action: forward, left or right.
#
# action:  forward
#
# action_id:  2
#
# episode_id:  1
#
# step:  1
#
# env_size:  8
#
# agent_pos:  (np.int64(4), np.int64(5))
#
# agent_dir:  0
